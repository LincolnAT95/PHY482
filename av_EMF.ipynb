# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d


t = np.arange(0,10,0.1)
a = np.arange(-10,10,0.5)
v = np.arange(0,20,0.5)

a_t = []
v_t = []

for i in range(len(t)):
    for j in range(len(a)):
        a_t.append(a[j]*t[i])
        
for i in range(len(t)):
    for j in range(len(v)):
        v_t.append(v[j]*t[i])
        
X, Y  = np.meshgrid(a_t, v_t)

def emf(x,y):
    return x + y*(1+x)

Z = emf(X,Y)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-d35a927f6829> in <module>
#       2 ax = plt.axes(projection='3d')
#       3
# ----> 4 ax.contour3D(X, Y, Z, 50, cmap='binary')
#       5 ax.set_xlabel('x')
#       6 ax.set_ylabel('y')
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in contour(self, X, Y, Z, extend3d, stride, zdir, offset, *args, **kwargs)
#    2078         jX, jY, jZ = art3d.rotate_axes(X, Y, Z, zdir)
#    2079         cset = super().contour(jX, jY, jZ, *args, **kwargs)
# -> 2080         self.add_contour_set(cset, extend3d, stride, zdir, offset)
#    2081
#    2082         self.auto_scale_xyz(X, Y, Z, had_data)
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in add_contour_set(self, cset, extend3d, stride, zdir, offset)
#    2041                 if offset is not None:
#    2042                     z = offset
# -> 2043                 art3d.line_collection_2d_to_3d(linec, z, zdir=zdir)
#    2044
#    2045     def add_contourf_set(self, cset, zdir='z', offset=None):
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/mpl_toolkits/mplot3d/art3d.py in line_collection_2d_to_3d(col, zs, zdir)
#     262 def line_collection_2d_to_3d(col, zs=0, zdir='z'):
#     263     """Convert a LineCollection to a Line3DCollection object."""
# --> 264     segments3d = paths_to_3d_segments(col.get_paths(), zs, zdir)
#     265     col.__class__ = Line3DCollection
#     266     col.set_segments(segments3d)
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/mpl_toolkits/mplot3d/art3d.py in paths_to_3d_segments(paths, zs, zdir)
#     187     zs = np.broadcast_to(zs, len(paths))
#     188     segs = [path_to_3d_segment(path, pathz, zdir)
# --> 189             for path, pathz in zip(paths, zs)]
#     190     return segs
#     191
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/mpl_toolkits/mplot3d/art3d.py in <listcomp>(.0)
#     187     zs = np.broadcast_to(zs, len(paths))
#     188     segs = [path_to_3d_segment(path, pathz, zdir)
# --> 189             for path, pathz in zip(paths, zs)]
#     190     return segs
#     191
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/mpl_toolkits/mplot3d/art3d.py in path_to_3d_segment(path, zs, zdir)
#     177     zs = np.broadcast_to(zs, len(path))
#     178     pathsegs = path.iter_segments(simplify=False, curves=False)
# --> 179     seg = [(x, y, z) for (((x, y), code), z) in zip(pathsegs, zs)]
#     180     seg3d = [juggle_axes(x, y, z, zdir) for (x, y, z) in seg]
#     181     return seg3d
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/mpl_toolkits/mplot3d/art3d.py in <listcomp>(.0)
#     177     zs = np.broadcast_to(zs, len(path))
#     178     pathsegs = path.iter_segments(simplify=False, curves=False)
# --> 179     seg = [(x, y, z) for (((x, y), code), z) in zip(pathsegs, zs)]
#     180     seg3d = [juggle_axes(x, y, z, zdir) for (x, y, z) in seg]
#     181     return seg3d
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/matplotlib/path.py in iter_segments(self, transform, remove_nans, clip, snap, stroke_width, simplify, curves, sketch)
#     424             else:
#     425                 num_vertices = NUM_VERTICES_FOR_CODE[code]
# --> 426                 curr_vertices = vertices[i:i+num_vertices].flatten()
#     427                 yield curr_vertices, code
#     428                 i += num_vertices
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x11dd86048> (for post_execute):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for f_mgr in cls.get_all_fig_managers():
#     131             if force or f_mgr.canvas.figure.stale:
# --> 132                 f_mgr.canvas.draw_idle()
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1897         if not self._is_idle_drawing:
#    1898             with self._idle_draw_cntx():
# -> 1899                 self.draw(*args, **kwargs)
#    1900
#    1901     def draw_cursor(self, event):
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     285                 sorted(self.collections,
#     286                        key=lambda col: col.do_3d_projection(renderer),
# --> 287                        reverse=True)):
#     288             col.zorder = zorder_offset + i
#     289         for i, patch in enumerate(
#
# /Applications/Anaconda/anaconda3/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in <lambda>(col)
#     284         for i, col in enumerate(
#     285                 sorted(self.collections,
# --> 286                        key=lambda col: col.do_3d_projection(renderer),
#     287                        reverse=True)):
#     288             col.zorder = zorder_offset + i
#
# AttributeError: 'LineCollection' object has no attribute 'do_3d_projection'
